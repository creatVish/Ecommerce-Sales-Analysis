# %% [markdown]
# <a href="https://colab.research.google.com/github/creatVish/Ecommerce-Sales-Analysis/blob/main/Ecommerce(CustTable).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cust = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Odin Collab/ecommerce sales analysis/customer_dim.csv')

# %%
cust.head()
# Out:
#   coustomer_key             name    contact_no    nationalID
# 0       C000001            sumit  8.801920e+12  7.505080e+12
# 1       C000002         tammanne  8.801820e+12  1.977730e+12
# 2       C000003    kailash kumar  8.801660e+12  3.769490e+12
# 3       C000004  bhagwati prasad  8.801530e+12  9.378830e+12
# 4       C000005             ajay  8.801940e+12  3.540820e+12

# %%
cust.rename(columns={'NID' : 'nationalID'}, inplace=True)

# %%
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9191 entries, 0 to 9190
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   coustomer_key  9191 non-null   object
#  1   name           9164 non-null   object
#  2   contact_no     9191 non-null   float64
#  3   nationalID     9191 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 287.3+ KB

# %%
cust.isnull().sum()
# Out:
# coustomer_key     0
# name             27
# contact_no        0
# nationalID        0
# dtype: int64

# %%
new_df = cust[cust['name'].isnull()]
new_df
# Out:
#      coustomer_key name    contact_no    nationalID
# 136        C000137  NaN  8.801550e+12  2.427030e+12
# 879        C000880  NaN  8.801590e+12  5.352980e+12
# 1170       C001171  NaN  8.801950e+12  3.470350e+12
# 1228       C001229  NaN  8.801820e+12  6.854480e+12
# 1267       C001268  NaN  8.801530e+12  2.195830e+12
# 1376       C001377  NaN  8.801840e+12  6.223860e+12
# 1656       C001657  NaN  8.801830e+12  8.909700e+12
# 1760       C001761  NaN  8.801780e+12  7.434900e+12
# 1769       C001770  NaN  8.801960e+12  7.629230e+12
# 2071       C002072  NaN  8.801690e+12  7.482560e+12
# 2191       C002192  NaN  8.801780e+12  3.853660e+12
# 3172       C003173  NaN  8.801690e+12  2.190860e+12
# 3269       C003270  NaN  8.801880e+12  7.484530e+12
# 3471       C003472  NaN  8.801980e+12  3.225700e+12
# 4217       C004218  NaN  8.801930e+12  6.759620e+12
# 4240       C004241  NaN  8.801510e+12  8.380120e+12
# 4450       C004451  NaN  8.801770e+12  4.547180e+12
# ...

# %%
cust.dropna(subset=['name'], inplace=True)

# %%
cust.isnull().sum()
# Out:
# coustomer_key    0
# name             0
# contact_no       0
# nationalID       0
# dtype: int64

# %%
cust.describe(include ='all')
# Out:
#        coustomer_key   name    contact_no    nationalID
# count           9164   9164  9.164000e+03  9.164000e+03
# unique          9164   4534           NaN           NaN
# top          C000001  pooja           NaN           NaN
# freq               1    185           NaN           NaN
# mean             NaN    NaN  8.801753e+12  5.480708e+12
# std              NaN    NaN  1.439822e+08  2.624605e+12
# min              NaN    NaN  8.801510e+12  1.000820e+12
# 25%              NaN    NaN  8.801630e+12  3.167150e+12
# 50%              NaN    NaN  8.801750e+12  5.467775e+12
# 75%              NaN    NaN  8.801880e+12  7.779442e+12
# max              NaN    NaN  8.802000e+12  9.998930e+12

# %%
cust.duplicated().sum()
# Out:
# 0
